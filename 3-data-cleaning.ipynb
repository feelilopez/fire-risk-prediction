# %% [markdown]
# # 3. Data cleaning

# %% [markdown]
# ## 3.1 Import libraries and load data

# %%
import numpy as np
import pandas as pd

# %%
# baseline
baseline_train = pd.read_parquet("data/baseline/train", engine="pyarrow")
baseline_val = pd.read_parquet("data/baseline/val", engine="pyarrow")
baseline_test = pd.read_parquet("data/baseline/test", engine="pyarrow")

# lstm
lstm_train = pd.read_parquet("data/lstm/train", engine="pyarrow")
lstm_val = pd.read_parquet("data/lstm/val", engine="pyarrow")
lstm_test = pd.read_parquet("data/lstm/test", engine="pyarrow")
